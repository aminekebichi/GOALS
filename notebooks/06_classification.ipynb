# %% [markdown]
# # 06 — Classification
#
# Predict match outcome (Win / Draw / Loss) from aggregated team composite scores.
#
# Models: Logistic Regression, Random Forest. class_weight='balanced'. Evaluation: macro F1, confusion matrix.

# %%
import pandas as pd
import numpy as np
from pathlib import Path
