# %% [markdown]
# # 03 — Feature Engineering
#
# Z-score normalisation (fit on train only) and position-aware composite score construction.
#
# Scores: ATT, MID, DEF, GK — weighted sums of normalised per-match metrics.

# %%
import pandas as pd
import numpy as np
from pathlib import Path
