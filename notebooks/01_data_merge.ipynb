# %% [markdown]
# # 01 — Data Merge
#
# Join FBref season-level stats with FotMob per-match stats on (player_name fuzzy, match_date, team).
#
# Outputs a unified player-match DataFrame covering all 4 La Liga seasons.

# %%
import pandas as pd
import numpy as np
from pathlib import Path
