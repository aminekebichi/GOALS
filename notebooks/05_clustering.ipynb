# %% [markdown]
# # 05 — Clustering
#
# K-Means player archetype discovery on normalised composite scores + position features.
#
# Evaluation: Silhouette Score, Elbow Method (inertia vs k), PCA cluster visualisation.

# %%
import pandas as pd
import numpy as np
from pathlib import Path
