# %% [markdown]
# # 04 — Regression
#
# Predict composite performance scores using Ridge Regression and Random Forest.
#
# Time-series-aware walk-forward CV within training seasons. Evaluation: RMSE, MAE, R².

# %%
import pandas as pd
import numpy as np
from pathlib import Path
